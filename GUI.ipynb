# %%
from tkinter import *
from tkinter import ttk
import json
#import the training.py
#and testing.py file
import testing as testpy
import training as trainpy

BG_GRAY="#ABB2B9"
BG_COLOR="#000"
TEXT_COLOR="#FFF"
FONT="Helvetica 14"
FONT_BOLD="Helvetica 13 bold"

class ChatBot:
    def __init__(self):
        #initialize tkinter window
        self.window=Tk()
        self.main_window()
        self.test=testpy.Testing()
        
    #run window
    def run(self):
        self.window.mainloop()
    
    def main_window(self):
        #add title to window and configure it
        self.window.title("Bayer")
        self.window.resizable(width=False,height=False)
        self.window.configure(width=520,height=520,bg=BG_COLOR)
        #add tab for Chatbot and Train Bot in Notebook frame
        self.tab = ttk.Notebook(self.window)
        self.tab.pack(expand=1,fill='both')
        self.bot_frame=ttk.Frame(self.tab,width=520,height=520)
        self.train_frame=ttk.Frame(self.tab,width=520,height=520)
        self.tab.add(self.bot_frame,text='Сайнуу'.center(100))
        self.tab.add(self.train_frame,text='Өөрөө Сургах'.center(100))
        self.add_bot()
        self.add_train()
        
    def add_bot(self):
        #Add heading to the Chabot window
        head_label=Label(self.bot_frame,bg=BG_COLOR,fg=TEXT_COLOR,text="Машинтай танилцах ашиглах",font=FONT_BOLD,pady=10)
        head_label.place(relwidth=1)
        line = Label(self.bot_frame,width=450,bg=BG_COLOR)
        line.place(relwidth=1,rely=0.07,relheight=0.012)

        #create text widget where conversation will be displayed
        self.text_widget=Text(self.bot_frame,width=20,height=2,bg="#fff",fg="#000",font=FONT,padx=5,pady=5)
        self.text_widget.place(relheight=0.745,relwidth=1,rely=0.08)
        self.text_widget.configure(cursor="arrow",state=DISABLED)

        #create scrollbar
        scrollbar=Scrollbar(self.text_widget)
        scrollbar.place(relheight=1,relx=0.974)
        scrollbar.configure(command=self.text_widget.yview)

        #create bottom label where message widget will placed
        bottom_label=Label(self.bot_frame,bg=BG_GRAY,height=80)
        bottom_label.place(relwidth=1,rely=0.825)
        #this is for user to put query
        self.msg_entry=Entry(bottom_label,bg="#2C3E50",fg=TEXT_COLOR,font=FONT)
        self.msg_entry.place(relwidth=0.788,relheight=0.06,rely=0.008,relx=0.008)
        self.msg_entry.focus()
        self.msg_entry.bind("<Return>",self.on_enter)
        #send button which will call on_enter function to send the query
        send_button=Button(bottom_label,text="Илгээх",font=FONT_BOLD,width=8,bg="Green",command=lambda: self.on_enter(None))   
        send_button.place(relx=0.80,rely=0.008,relheight=0.06,relwidth=0.20)

    def add_train(self):
        #Add heading to the Train Bot window
        head_label=Label(self.train_frame,bg=BG_COLOR,fg=TEXT_COLOR,text="Машин Сургалт",font=FONT_BOLD,pady=10)
        head_label.place(relwidth=1)

        #Tag Label and Entry for intents tag. 
        taglabel=Label(self.train_frame,fg="#000",text="Төрөл",font=FONT)
        taglabel.place(relwidth=0.2,rely=0.14,relx=0.008)
        self.tag=Entry(self.train_frame,bg="#fff",fg="#000",font=FONT)
        self.tag.place(relwidth=0.7,relheight=0.06,rely=0.14,relx=0.22)

        #Pattern Label and Entry for pattern to our tag.
        self.pattern=[]
        for i in range(2):
            patternlabel=Label(self.train_frame,fg="#000",text="Загвар%d"%(i+1),font=FONT)
            patternlabel.place(relwidth=0.2,rely=0.28+0.08*i,relx=0.008)
            self.pattern.append(Entry(self.train_frame,bg="#fff",fg="#000",font=FONT))
            self.pattern[i].place(relwidth=0.7,relheight=0.06,rely=0.28+0.08*i,relx=0.22)

        #Response Label and Entry for response to our pattern.
        self.response=[]
        for i in range(2):
            responselabel=Label(self.train_frame,fg="#000",text="Хариултууд%d"%(i+1),font=FONT)
            responselabel.place(relwidth=0.2,rely=0.50+0.08*i,relx=0.008)
            self.response.append(Entry(self.train_frame,bg="#fff",fg="#000",font=FONT))
            self.response[i].place(relwidth=0.7,relheight=0.06,rely=0.50+0.08*i,relx=0.22)

        #to train our bot create Train Bot button which will call on_train function
        bottom_label=Label(self.train_frame,bg=BG_GRAY,height=80)
        bottom_label.place(relwidth=1,rely=0.825)

        train_button=Button(bottom_label,text="Сургах",font=FONT_BOLD,width=12,bg="Green",command=lambda: self.on_train(None))
        train_button.place(relx=0.20,rely=0.008,relheight=0.06,relwidth=0.60)
    
    def on_train(self,event):
        #read intent file and append created tag,pattern and responses from add_train function
        with open('intents1.json','r+') as json_file:
            file_data=json.load(json_file)
            file_data['intents'].append({
            "Төрөл": self.tag.get(),
            "Загварууд": [i.get() for i in self.pattern],
            "Хариултууд": [i.get() for i in self.response],
            "context": ""
            })
            json_file.seek(0)
            json.dump(file_data, json_file, indent = 1)
        #run and compile model from our training.py file.
        train=trainpy.Training()
        train.build(); print("Амжилттай Сурчлаа")
        self.test=testpy.Testing()
        
    def on_enter(self,event):
        #get user query and bot response
        msg=self.msg_entry.get()
        self.my_msg(msg,"You")
        self.bot_response(msg,"Bot")
        
    def bot_response(self,msg,sender):
        self.text_widget.configure(state=NORMAL)
        #get the response for the user's query from testing.py file
        self.text_widget.insert(END,str(sender)+" : "+self.test.response(msg)+"\n\n")
        self.text_widget.configure(state=DISABLED)
        self.text_widget.see(END)
    
    def my_msg(self,msg,sender):
        #it will display user query and bot response in text_widget
        if not msg:
            return
        self.msg_entry.delete(0,END)
        self.text_widget.configure(state=NORMAL)
        self.text_widget.insert(END,str(sender)+" : "+str(msg)+"\n")
        self.text_widget.configure(state=DISABLED)
        
# run the file
if __name__=="__main__":
    bot = ChatBot()
    bot.run()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Developer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Developer\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# WARNING:tensorflow:From C:\Users\Developer\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/200
# WARNING:tensorflow:From C:\Users\Developer\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Developer\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 10/10 [==============================] - 2s 4ms/step - loss: 4.0294 - accuracy: 0.0200
# Epoch 2/200
# 10/10 [==============================] - 0s 5ms/step - loss: 3.9759 - accuracy: 0.0400
# Epoch 3/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.9828 - accuracy: 0.0300
# Epoch 4/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.9103 - accuracy: 0.1300
# Epoch 5/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.8805 - accuracy: 0.1300
# Epoch 6/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.8355 - accuracy: 0.1200
# Epoch 7/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.8231 - accuracy: 0.1400
# Epoch 8/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.7342 - accuracy: 0.1700
# Epoch 9/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.7072 - accuracy: 0.1700
# Epoch 10/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.6709 - accuracy: 0.1500
# Epoch 11/200
# 10/10 [==============================] - 0s 5ms/step - loss: 3.5698 - accuracy: 0.1800
# Epoch 12/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.5672 - accuracy: 0.2000
# Epoch 13/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.5380 - accuracy: 0.1700
# Epoch 14/200
# 10/10 [==============================] - 0s 5ms/step - loss: 3.4553 - accuracy: 0.2500
# Epoch 15/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.4292 - accuracy: 0.2200
# Epoch 16/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.3366 - accuracy: 0.2300
# Epoch 17/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.3704 - accuracy: 0.1100
# Epoch 18/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.2820 - accuracy: 0.2400
# Epoch 19/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.3059 - accuracy: 0.2500
# Epoch 20/200
# 10/10 [==============================] - 0s 3ms/step - loss: 3.1782 - accuracy: 0.2100
# Epoch 21/200
# 10/10 [==============================] - 0s 3ms/step - loss: 3.0830 - accuracy: 0.2800
# Epoch 22/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.0471 - accuracy: 0.2400
# Epoch 23/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9797 - accuracy: 0.2600
# Epoch 24/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9369 - accuracy: 0.2700
# Epoch 25/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.8886 - accuracy: 0.3500
# Epoch 26/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.7274 - accuracy: 0.3200
# Epoch 27/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.7222 - accuracy: 0.3300
# Epoch 28/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.6479 - accuracy: 0.3100
# Epoch 29/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6508 - accuracy: 0.3000
# Epoch 30/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.5905 - accuracy: 0.3700
# Epoch 31/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5510 - accuracy: 0.3700
# Epoch 32/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4763 - accuracy: 0.4200
# Epoch 33/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5140 - accuracy: 0.3600
# Epoch 34/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3334 - accuracy: 0.4100
# Epoch 35/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3892 - accuracy: 0.4300
# Epoch 36/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2207 - accuracy: 0.4200
# Epoch 37/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.3405 - accuracy: 0.4000
# Epoch 38/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2368 - accuracy: 0.3900
# Epoch 39/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0509 - accuracy: 0.4900
# Epoch 40/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1188 - accuracy: 0.4800
# Epoch 41/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0348 - accuracy: 0.4800
# Epoch 42/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9710 - accuracy: 0.4700
# Epoch 43/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.1009 - accuracy: 0.4500
# Epoch 44/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.9814 - accuracy: 0.5000
# Epoch 45/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9422 - accuracy: 0.4900
# Epoch 46/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7666 - accuracy: 0.5500
# Epoch 47/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7714 - accuracy: 0.5700
# Epoch 48/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8059 - accuracy: 0.4700
# Epoch 49/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.6421 - accuracy: 0.5900
# Epoch 50/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6372 - accuracy: 0.5800
# Epoch 51/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6497 - accuracy: 0.5800
# Epoch 52/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6319 - accuracy: 0.5800
# Epoch 53/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6052 - accuracy: 0.6100
# Epoch 54/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5050 - accuracy: 0.6000
# Epoch 55/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5114 - accuracy: 0.6200
# Epoch 56/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.5043 - accuracy: 0.6000
# Epoch 57/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4437 - accuracy: 0.5600
# Epoch 58/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4923 - accuracy: 0.6100
# Epoch 59/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3593 - accuracy: 0.6100
# Epoch 60/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4067 - accuracy: 0.5600
# Epoch 61/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2655 - accuracy: 0.6800
# Epoch 62/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2810 - accuracy: 0.6400
# Epoch 63/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2480 - accuracy: 0.6900
# Epoch 64/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4769 - accuracy: 0.5800
# Epoch 65/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2902 - accuracy: 0.6800
# Epoch 66/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2168 - accuracy: 0.6300
# Epoch 67/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2582 - accuracy: 0.6900
# Epoch 68/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3577 - accuracy: 0.6000
# Epoch 69/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1315 - accuracy: 0.7400
# Epoch 70/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2708 - accuracy: 0.6200
# Epoch 71/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1514 - accuracy: 0.6800
# Epoch 72/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1571 - accuracy: 0.6900
# Epoch 73/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.1918 - accuracy: 0.6700
# Epoch 74/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2492 - accuracy: 0.6500
# Epoch 75/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1038 - accuracy: 0.7100
# Epoch 76/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1807 - accuracy: 0.6900
# Epoch 77/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0935 - accuracy: 0.7000
# Epoch 78/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0174 - accuracy: 0.7100
# Epoch 79/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1413 - accuracy: 0.6300
# Epoch 80/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9588 - accuracy: 0.7200
# Epoch 81/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8873 - accuracy: 0.7400
# Epoch 82/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1534 - accuracy: 0.6700
# Epoch 83/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8723 - accuracy: 0.7400
# Epoch 84/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8382 - accuracy: 0.7800
# Epoch 85/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9055 - accuracy: 0.7500
# Epoch 86/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0199 - accuracy: 0.7000
# Epoch 87/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7542 - accuracy: 0.8200
# Epoch 88/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8897 - accuracy: 0.7900
# Epoch 89/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0349 - accuracy: 0.6600
# Epoch 90/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7827 - accuracy: 0.7900
# Epoch 91/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8480 - accuracy: 0.7600
# Epoch 92/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9988 - accuracy: 0.7000
# Epoch 93/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6966 - accuracy: 0.8000
# Epoch 94/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7137 - accuracy: 0.8200
# Epoch 95/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7986 - accuracy: 0.7600
# Epoch 96/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7465 - accuracy: 0.8300
# Epoch 97/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9095 - accuracy: 0.7500
# Epoch 98/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9699 - accuracy: 0.7000
# Epoch 99/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7734 - accuracy: 0.8000
# Epoch 100/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6740 - accuracy: 0.8100
# Epoch 101/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8261 - accuracy: 0.7500
# Epoch 102/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7354 - accuracy: 0.7700
# Epoch 103/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7542 - accuracy: 0.8000
# Epoch 104/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6788 - accuracy: 0.8600
# Epoch 105/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8774 - accuracy: 0.7200
# Epoch 106/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7258 - accuracy: 0.7800
# Epoch 107/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7795 - accuracy: 0.7400
# Epoch 108/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6980 - accuracy: 0.7800
# Epoch 109/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6750 - accuracy: 0.8200
# Epoch 110/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6522 - accuracy: 0.8400
# Epoch 111/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6224 - accuracy: 0.8300
# Epoch 112/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6476 - accuracy: 0.8500
# Epoch 113/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5809 - accuracy: 0.8400
# Epoch 114/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5924 - accuracy: 0.8700
# Epoch 115/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5001 - accuracy: 0.9000
# Epoch 116/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7523 - accuracy: 0.7800
# Epoch 117/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6143 - accuracy: 0.8000
# Epoch 118/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6911 - accuracy: 0.8100
# Epoch 119/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6303 - accuracy: 0.7600
# Epoch 120/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6681 - accuracy: 0.7900
# Epoch 121/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5554 - accuracy: 0.8400
# Epoch 122/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6093 - accuracy: 0.7900
# Epoch 123/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6748 - accuracy: 0.7400
# Epoch 124/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6236 - accuracy: 0.8000
# Epoch 125/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5386 - accuracy: 0.8700
# Epoch 126/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6372 - accuracy: 0.7900
# Epoch 127/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6739 - accuracy: 0.7900
# Epoch 128/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5932 - accuracy: 0.8200
# Epoch 129/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3954 - accuracy: 0.9200
# Epoch 130/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4927 - accuracy: 0.8400
# Epoch 131/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4943 - accuracy: 0.8800
# Epoch 132/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5587 - accuracy: 0.8200
# Epoch 133/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6371 - accuracy: 0.8100
# Epoch 134/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4845 - accuracy: 0.8600
# Epoch 135/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5085 - accuracy: 0.8900
# Epoch 136/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5351 - accuracy: 0.8600
# Epoch 137/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5041 - accuracy: 0.8500
# Epoch 138/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6347 - accuracy: 0.8000
# Epoch 139/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5719 - accuracy: 0.8300
# Epoch 140/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4444 - accuracy: 0.8900
# Epoch 141/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5110 - accuracy: 0.8500
# Epoch 142/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5964 - accuracy: 0.8300
# Epoch 143/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4110 - accuracy: 0.9000
# Epoch 144/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4502 - accuracy: 0.8800
# Epoch 145/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5228 - accuracy: 0.8600
# Epoch 146/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5460 - accuracy: 0.8600
# Epoch 147/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4918 - accuracy: 0.8600
# Epoch 148/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4223 - accuracy: 0.8800
# Epoch 149/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5320 - accuracy: 0.8600
# Epoch 150/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5758 - accuracy: 0.8400
# Epoch 151/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4192 - accuracy: 0.8800
# Epoch 152/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4915 - accuracy: 0.8500
# Epoch 153/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5450 - accuracy: 0.8300
# Epoch 154/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4876 - accuracy: 0.8500
# Epoch 155/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3735 - accuracy: 0.8900
# Epoch 156/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4613 - accuracy: 0.8700
# Epoch 157/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4371 - accuracy: 0.8500
# Epoch 158/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3739 - accuracy: 0.8800
# Epoch 159/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4942 - accuracy: 0.8700
# Epoch 160/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3211 - accuracy: 0.9100
# Epoch 161/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4204 - accuracy: 0.8900
# Epoch 162/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5040 - accuracy: 0.8300
# Epoch 163/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4283 - accuracy: 0.9000
# Epoch 164/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4929 - accuracy: 0.8200
# Epoch 165/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4177 - accuracy: 0.8900
# Epoch 166/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4229 - accuracy: 0.8300
# Epoch 167/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3655 - accuracy: 0.9000
# Epoch 168/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3817 - accuracy: 0.8900
# Epoch 169/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4483 - accuracy: 0.8800
# Epoch 170/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3224 - accuracy: 0.9000
# Epoch 171/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5162 - accuracy: 0.8700
# Epoch 172/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3667 - accuracy: 0.9200
# Epoch 173/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3704 - accuracy: 0.8500
# Epoch 174/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4316 - accuracy: 0.8500
# Epoch 175/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4116 - accuracy: 0.8700
# Epoch 176/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3420 - accuracy: 0.8600
# Epoch 177/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3952 - accuracy: 0.8900
# Epoch 178/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4269 - accuracy: 0.8500
# Epoch 179/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4796 - accuracy: 0.8700
# Epoch 180/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5138 - accuracy: 0.8200
# Epoch 181/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3786 - accuracy: 0.8600
# Epoch 182/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3715 - accuracy: 0.8800
# Epoch 183/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3224 - accuracy: 0.9100
# Epoch 184/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3398 - accuracy: 0.9000
# Epoch 185/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3637 - accuracy: 0.9200
# Epoch 186/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3144 - accuracy: 0.9100
# Epoch 187/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4632 - accuracy: 0.8400
# Epoch 188/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4001 - accuracy: 0.9000
# Epoch 189/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3095 - accuracy: 0.9000
# Epoch 190/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3884 - accuracy: 0.9000
# Epoch 191/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3189 - accuracy: 0.9100
# Epoch 192/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4280 - accuracy: 0.8300
# Epoch 193/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4378 - accuracy: 0.8600
# Epoch 194/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3264 - accuracy: 0.8800
# Epoch 195/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4789 - accuracy: 0.8300
# Epoch 196/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3972 - accuracy: 0.9000
# Epoch 197/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2744 - accuracy: 0.9400
# Epoch 198/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3510 - accuracy: 0.9000
# Epoch 199/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2966 - accuracy: 0.9200
# Epoch 200/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3804 - accuracy: 0.8700
# C:\Users\Developer\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
