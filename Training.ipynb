# %%
# Import necessary libraries
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk import flatten
import numpy as np
import random
import json
import pickle
from sklearn.feature_extraction.text import CountVectorizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import tensorflow as tf


nltk.download('punkt')
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()

class Training:
    def __init__(self):
        # read and load the intent file
        data_file = open('intents1.json').read()
        self.intents = json.loads(data_file)['intents']
        self.ignore_words = list("!@#$%^&*?")
        self.process_data()

    def process_data(self):
        # fetch patterns and tokenize them into words
        self.pattern = list(map(lambda x: x["patterns"], self.intents))
        self.words = list(map(word_tokenize, flatten(self.pattern)))
        # fetch classes i.e. tags and store in documents along with tokenized patterns
        self.classes = flatten([[x["tag"]] * len(y) for x, y in zip(self.intents, self.pattern)])
        self.documents = list(map(lambda x, y: (x, y), self.words, self.classes))
        # lower case and filter all the symbols from words
        self.words = list(map(str.lower, flatten(self.words)))
        self.words = list(filter(lambda x: x not in self.ignore_words, self.words))

        # lemmatize the words and sort the class and word lists
        self.words = list(map(lemmatizer.lemmatize, self.words))
        self.words = sorted(list(set(self.words)))
        self.classes = sorted(list(set(self.classes)))

    def train_data(self):
        # initialize and set analyzer=word as we want to vectorize words not characters
        cv = CountVectorizer(tokenizer=lambda txt: txt.split(), analyzer="word", stop_words=None)
        # create the training sets for the model
        training = []
        for doc in self.documents:
            # lower case and lemmatize the pattern words
            pattern_words = list(map(str.lower, doc[0]))
            pattern_words = ' '.join(list(map(lemmatizer.lemmatize, pattern_words)))

            # train or fit the vectorizer with all words
            # and transform into one-hot encoded vector
            vectorize = cv.fit([' '.join(self.words)])
            word_vector = vectorize.transform([pattern_words]).toarray().tolist()[0]

            # create output for the respective input
            # output size will be equal to the total number of classes
            output_row = [0] * len(self.classes)
            output_row[self.classes.index(doc[1])] = 1

            cvop = cv.fit([' '.join(self.classes)])
            out_p = cvop.transform([doc[1]]).toarray().tolist()[0]

            # store vectorized word list along with its class
            training.append([word_vector, output_row])

        # shuffle training sets to avoid the model training on the same data again
        random.shuffle(training)
        training = np.array(training, dtype=object)
        train_x = list(training[:, 0])  # patterns
        train_y = list(training[:, 1])  # classes
        return train_x, train_y

    def build(self):
        # load the data from train_data function
        train_x, train_y = self.train_data()

        # Create a Sequential model with 3 layers.
        model = Sequential()
        # input layer with a latent dimension of 128 neurons and ReLU activation function
        model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
        model.add(Dropout(0.5))  # Dropout to avoid overfitting
        # second layer with the latent dimension of 64 neurons
        model.add(Dense(64, activation='relu'))
        model.add(Dropout(0.5))
        # fully connected output layer with softmax activation function
        model.add(Dense(len(train_y[0]), activation='softmax'))
       # Compile model with legacy Stochastic Gradient Descent
        sgd = tf.keras.optimizers.legacy.SGD(learning_rate=1e-2, decay=1e-6, momentum=0.9, nesterov=True)
        model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])



        # fit the model with training input and output sets
        hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=10, verbose=1)
        # save the model and words, classes which can be used for prediction.
        model.save('NewModel.h5')
        pickle.dump({'words': self.words, 'classes': self.classes, 'train_x': train_x, 'train_y': train_y},
                    open("training_data", "wb"))

# train the model
Training().build()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Developer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Developer\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Epoch 1/200
# 10/10 [==============================] - 1s 5ms/step - loss: 4.0231 - accuracy: 0.0100
# Epoch 2/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.9763 - accuracy: 0.0200
# Epoch 3/200
# 10/10 [==============================] - 0s 5ms/step - loss: 3.9775 - accuracy: 0.0600
# Epoch 4/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.9067 - accuracy: 0.1200
# Epoch 5/200
# 10/10 [==============================] - 0s 5ms/step - loss: 3.8803 - accuracy: 0.1600
# Epoch 6/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.7837 - accuracy: 0.1500
# Epoch 7/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.7809 - accuracy: 0.1600
# Epoch 8/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.6847 - accuracy: 0.1800
# Epoch 9/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.7162 - accuracy: 0.1400
# Epoch 10/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.6031 - accuracy: 0.2100
# Epoch 11/200
# 10/10 [==============================] - 0s 3ms/step - loss: 3.4950 - accuracy: 0.2300
# Epoch 12/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.5122 - accuracy: 0.2100
# Epoch 13/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.3958 - accuracy: 0.1900
# Epoch 14/200
# 10/10 [==============================] - 0s 5ms/step - loss: 3.4527 - accuracy: 0.2100
# Epoch 15/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.3809 - accuracy: 0.2100
# Epoch 16/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.3198 - accuracy: 0.1800
# Epoch 17/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.3251 - accuracy: 0.2300
# Epoch 18/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.2042 - accuracy: 0.2400
# Epoch 19/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.1241 - accuracy: 0.3000
# Epoch 20/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.1488 - accuracy: 0.2400
# Epoch 21/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9651 - accuracy: 0.2400
# Epoch 22/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9191 - accuracy: 0.3500
# Epoch 23/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8182 - accuracy: 0.3100
# Epoch 24/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.7912 - accuracy: 0.3400
# Epoch 25/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8225 - accuracy: 0.2900
# Epoch 26/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8617 - accuracy: 0.3100
# Epoch 27/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6510 - accuracy: 0.3500
# Epoch 28/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.6074 - accuracy: 0.3700
# Epoch 29/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6786 - accuracy: 0.3300
# Epoch 30/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4510 - accuracy: 0.3700
# Epoch 31/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5193 - accuracy: 0.3800
# Epoch 32/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5023 - accuracy: 0.3300
# Epoch 33/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4057 - accuracy: 0.4000
# Epoch 34/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2569 - accuracy: 0.4300
# Epoch 35/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1929 - accuracy: 0.4300
# Epoch 36/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2735 - accuracy: 0.3600
# Epoch 37/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3633 - accuracy: 0.3800
# Epoch 38/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1582 - accuracy: 0.4300
# Epoch 39/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1542 - accuracy: 0.4400
# Epoch 40/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1084 - accuracy: 0.4200
# Epoch 41/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1080 - accuracy: 0.4900
# Epoch 42/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0771 - accuracy: 0.4200
# Epoch 43/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9771 - accuracy: 0.4800
# Epoch 44/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8474 - accuracy: 0.5100
# Epoch 45/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9619 - accuracy: 0.4600
# Epoch 46/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8232 - accuracy: 0.5200
# Epoch 47/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8274 - accuracy: 0.5000
# Epoch 48/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7235 - accuracy: 0.5600
# Epoch 49/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8758 - accuracy: 0.5100
# Epoch 50/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7952 - accuracy: 0.5100
# Epoch 51/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8274 - accuracy: 0.5700
# Epoch 52/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6664 - accuracy: 0.5100
# Epoch 53/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5330 - accuracy: 0.6200
# Epoch 54/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.5528 - accuracy: 0.5700
# Epoch 55/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5192 - accuracy: 0.6000
# Epoch 56/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.6333 - accuracy: 0.5200
# Epoch 57/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.5481 - accuracy: 0.6000
# Epoch 58/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3588 - accuracy: 0.6200
# Epoch 59/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4749 - accuracy: 0.5900
# Epoch 60/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.3972 - accuracy: 0.6500
# Epoch 61/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3953 - accuracy: 0.5900
# Epoch 62/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1631 - accuracy: 0.7400
# Epoch 63/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3184 - accuracy: 0.6400
# Epoch 64/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2130 - accuracy: 0.6300
# Epoch 65/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.4171 - accuracy: 0.6200
# Epoch 66/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.3334 - accuracy: 0.6300
# Epoch 67/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2677 - accuracy: 0.6200
# Epoch 68/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3358 - accuracy: 0.6300
# Epoch 69/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.0833 - accuracy: 0.7800
# Epoch 70/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2793 - accuracy: 0.6400
# Epoch 71/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0815 - accuracy: 0.7400
# Epoch 72/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0183 - accuracy: 0.7300
# Epoch 73/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9849 - accuracy: 0.7000
# Epoch 74/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1756 - accuracy: 0.6700
# Epoch 75/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0661 - accuracy: 0.6900
# Epoch 76/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0627 - accuracy: 0.7000
# Epoch 77/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0633 - accuracy: 0.6700
# Epoch 78/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0632 - accuracy: 0.6600
# Epoch 79/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9975 - accuracy: 0.7300
# Epoch 80/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8372 - accuracy: 0.7700
# Epoch 81/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9180 - accuracy: 0.7400
# Epoch 82/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9219 - accuracy: 0.7000
# Epoch 83/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9769 - accuracy: 0.7300
# Epoch 84/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.0901 - accuracy: 0.7300
# Epoch 85/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9366 - accuracy: 0.7200
# Epoch 86/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8476 - accuracy: 0.7900
# Epoch 87/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9185 - accuracy: 0.7300
# Epoch 88/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7765 - accuracy: 0.7600
# Epoch 89/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8724 - accuracy: 0.7800
# Epoch 90/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0633 - accuracy: 0.6900
# Epoch 91/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9151 - accuracy: 0.7500
# Epoch 92/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9845 - accuracy: 0.7300
# Epoch 93/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8584 - accuracy: 0.7800
# Epoch 94/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8729 - accuracy: 0.7600
# Epoch 95/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8087 - accuracy: 0.7500
# Epoch 96/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8261 - accuracy: 0.7400
# Epoch 97/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9263 - accuracy: 0.7200
# Epoch 98/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7201 - accuracy: 0.7900
# Epoch 99/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8504 - accuracy: 0.7600
# Epoch 100/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9432 - accuracy: 0.7200
# Epoch 101/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7258 - accuracy: 0.7800
# Epoch 102/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6892 - accuracy: 0.8000
# Epoch 103/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7801 - accuracy: 0.7900
# Epoch 104/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7099 - accuracy: 0.8000
# Epoch 105/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7928 - accuracy: 0.7900
# Epoch 106/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6748 - accuracy: 0.8100
# Epoch 107/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7243 - accuracy: 0.8100
# Epoch 108/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6443 - accuracy: 0.8000
# Epoch 109/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5913 - accuracy: 0.8400
# Epoch 110/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6327 - accuracy: 0.8000
# Epoch 111/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6766 - accuracy: 0.8100
# Epoch 112/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5883 - accuracy: 0.8300
# Epoch 113/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6434 - accuracy: 0.8800
# Epoch 114/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5247 - accuracy: 0.8500
# Epoch 115/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6773 - accuracy: 0.8300
# Epoch 116/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7487 - accuracy: 0.7500
# Epoch 117/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5861 - accuracy: 0.8400
# Epoch 118/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4883 - accuracy: 0.8900
# Epoch 119/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5704 - accuracy: 0.8700
# Epoch 120/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.8296 - accuracy: 0.7800
# Epoch 121/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6356 - accuracy: 0.8400
# Epoch 122/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6133 - accuracy: 0.8100
# Epoch 123/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6360 - accuracy: 0.8600
# Epoch 124/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5821 - accuracy: 0.7900
# Epoch 125/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5310 - accuracy: 0.8900
# Epoch 126/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6162 - accuracy: 0.8200
# Epoch 127/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4698 - accuracy: 0.8800
# Epoch 128/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5007 - accuracy: 0.8500
# Epoch 129/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4924 - accuracy: 0.8700
# Epoch 130/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5539 - accuracy: 0.8300
# Epoch 131/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5547 - accuracy: 0.8500
# Epoch 132/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3662 - accuracy: 0.9100
# Epoch 133/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4749 - accuracy: 0.8600
# Epoch 134/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3667 - accuracy: 0.8900
# Epoch 135/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4440 - accuracy: 0.9100
# Epoch 136/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5904 - accuracy: 0.8500
# Epoch 137/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6641 - accuracy: 0.8100
# Epoch 138/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3806 - accuracy: 0.9200
# Epoch 139/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3216 - accuracy: 0.9200
# Epoch 140/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4912 - accuracy: 0.8400
# Epoch 141/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5013 - accuracy: 0.8600
# Epoch 142/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5067 - accuracy: 0.8500
# Epoch 143/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4524 - accuracy: 0.8600
# Epoch 144/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5290 - accuracy: 0.8200
# Epoch 145/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4117 - accuracy: 0.8800
# Epoch 146/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5944 - accuracy: 0.8400
# Epoch 147/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4636 - accuracy: 0.8500
# Epoch 148/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3634 - accuracy: 0.9200
# Epoch 149/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4818 - accuracy: 0.8300
# Epoch 150/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4433 - accuracy: 0.8700
# Epoch 151/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4038 - accuracy: 0.9000
# Epoch 152/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3923 - accuracy: 0.8600
# Epoch 153/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4190 - accuracy: 0.9200
# Epoch 154/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4038 - accuracy: 0.9200
# Epoch 155/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5423 - accuracy: 0.8300
# Epoch 156/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5165 - accuracy: 0.8400
# Epoch 157/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5238 - accuracy: 0.8200
# Epoch 158/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5051 - accuracy: 0.8200
# Epoch 159/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4916 - accuracy: 0.8200
# Epoch 160/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4104 - accuracy: 0.8900
# Epoch 161/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4633 - accuracy: 0.8500
# Epoch 162/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3537 - accuracy: 0.9100
# Epoch 163/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4085 - accuracy: 0.9100
# Epoch 164/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4775 - accuracy: 0.8900
# Epoch 165/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4747 - accuracy: 0.8200
# Epoch 166/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3498 - accuracy: 0.8900
# Epoch 167/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4356 - accuracy: 0.8600
# Epoch 168/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3692 - accuracy: 0.9000
# Epoch 169/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2885 - accuracy: 0.9200
# Epoch 170/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4579 - accuracy: 0.8700
# Epoch 171/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4549 - accuracy: 0.8800
# Epoch 172/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4218 - accuracy: 0.8700
# Epoch 173/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3720 - accuracy: 0.9000
# Epoch 174/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3725 - accuracy: 0.9100
# Epoch 175/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3990 - accuracy: 0.9000
# Epoch 176/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3074 - accuracy: 0.9300
# Epoch 177/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2912 - accuracy: 0.9300
# Epoch 178/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3978 - accuracy: 0.9000
# Epoch 179/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2761 - accuracy: 0.9500
# Epoch 180/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3064 - accuracy: 0.9100
# Epoch 181/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3764 - accuracy: 0.8700
# Epoch 182/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3848 - accuracy: 0.9200
# Epoch 183/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4244 - accuracy: 0.8800
# Epoch 184/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2907 - accuracy: 0.9300
# Epoch 185/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3584 - accuracy: 0.9200
# Epoch 186/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5023 - accuracy: 0.8300
# Epoch 187/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4105 - accuracy: 0.8700
# Epoch 188/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3528 - accuracy: 0.9000
# Epoch 189/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4687 - accuracy: 0.8600
# Epoch 190/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2704 - accuracy: 0.9300
# Epoch 191/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3323 - accuracy: 0.8900
# Epoch 192/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3906 - accuracy: 0.8800
# Epoch 193/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2893 - accuracy: 0.9300
# Epoch 194/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2774 - accuracy: 0.9000
# Epoch 195/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2855 - accuracy: 0.9000
# Epoch 196/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4500 - accuracy: 0.8000
# Epoch 197/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3152 - accuracy: 0.9000
# Epoch 198/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3106 - accuracy: 0.9200
# Epoch 199/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2214 - accuracy: 0.9500
# Epoch 200/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4060 - accuracy: 0.9000
